# %%
from scripts.features.test.pose_features import extract_features_from_run

features = extract_features_from_run("run/test1")

# %%
features
# Out:
# {'postural_lean_deg': 12.170945530667202,
#  'torso_flexion_deg': 11.198949282404685,
#  'lean_variability_deg': 10.059992166330384,
#  'pelvis_to_ankle_ap_distance': 0.23325224289456378,
#  'peak_knee_flexion_stance_deg': 47.03259492234424,
#  'tibia_angle_deg': 60.06410946781106,
#  'hip_extension_late_stance_deg': 25.224915979281374,
#  'heel_to_com_ap_distance': 0.2639358302832077,
#  'overstride_asymmetry_pct': 1.325206113797323,
#  'knee_flexion_at_ic_deg': 36.674631014552226,
#  'max_knee_flexion_stance_deg': 47.03259492234424,
#  'knee_flexion_excursion_deg': 10.357963907792007,
#  'foot_inclination_at_ic_deg': 21.189887605045993,
#  'cadence_spm': 105.0,
#  'step_time_asymmetry_pct': 4.9382716049382855,
#  'estimated_stance_time_asymmetry_pct': 3.564843269821747,
#  'knee_rom_asymmetry_pct': 1.743082452236639,
#  'elbow_angle_rom_deg': 83.62914190242435}

# %%
from pathlib import Path
img_dir = Path("/Users/hyeon/SeSAC_Project/PoC/run/test2/inputs/")

# %%
image_paths = sorted(img_dir.glob("*.png"))

# %%
str(image_paths[0]).split('/')[-1]
# Out:
# '00000001.png'
